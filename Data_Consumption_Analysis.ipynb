# %% [markdown]
# <a href="https://colab.research.google.com/github/RasilaMoidheensha006/Rasila.github.io/blob/main/Data_Consumption_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded=files.upload()

# %%
data=pd.read_csv("phones_data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1224 non-null   int64
#  1   brand_name      1224 non-null   object
#  2   model_name      1224 non-null   object
#  3   os              1027 non-null   object
#  4   popularity      1224 non-null   int64
#  5   best_price      1224 non-null   int64
#  6   lowest_price    964 non-null    float64
#  7   highest_price   964 non-null    float64
#  8   sellers_amount  1224 non-null   int64
#  9   screen_size     1222 non-null   float64
#  10  memory_size     1112 non-null   float64
#  11  battery_size    1214 non-null   float64
#  12  release_date    1224 non-null   object
# dtypes: float64(5), int64(4), object(4)
# memory usage: 124.4+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# brand_name          0
# model_name          0
# os                197
# popularity          0
# best_price          0
# lowest_price      260
# highest_price     260
# sellers_amount      0
# screen_size         2
# memory_size       112
# battery_size       10
# release_date        0
# dtype: int64

# %%
data=data.interpolate()

# %%
data=data.fillna(0)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# brand_name        0
# model_name        0
# os                0
# popularity        0
# best_price        0
# lowest_price      0
# highest_price     0
# sellers_amount    0
# screen_size       0
# memory_size       0
# battery_size      0
# release_date      0
# dtype: int64

# %%
#Find out the best 5 prices of phones
data.sort_values(by=['highest_price'],ascending=False).head(6)
# Out:
#      Unnamed: 0 brand_name                                         model_name  \
# 298         600     HUAWEI       Mate Xs 8/512GB Interstellar blue (51095CSQ)
# 100        1156      Apple  iPhone 12 Pro Max 512GB Dual Sim Pacific Blue ...
# 563         432    Samsung                         Galaxy Fold 12/256GB Black
# 249         543    Samsung  Galaxy Z Fold2 12/256GB Mystic Black (SM-F916B...
# 180        1157      Apple       iPhone 12 Pro Max 512GB Pacific Blue (MGDL3)
# 772         433    Samsung           Galaxy Fold 12/512GB Black (SM-F900FZKD)
#
#           os  popularity  best_price  lowest_price  highest_price  \
# 298  Android         740       56082       49999.0        69999.0
# 100      iOS         872       49242       45120.0        64999.0
# 563  Android         298       55338       45799.0        59999.0
# 249  Android        1099       51460       44809.0        59999.0
# 180      iOS        1103       46325       43396.0        57999.0
# ...

# %%
#lowest of price
data[data['lowest_price']==data['lowest_price']].min()
# Out:
# <ipython-input-15-200a47cd4640>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data[data['lowest_price']==data['lowest_price']].min()
# Unnamed: 0                                           0
# brand_name                                          2E
# model_name        1 1/8GB Bluish Black (5033D-2JALUAA)
# popularity                                           1
# best_price                                         214
# lowest_price                                     198.0
# highest_price                                    229.0
# sellers_amount                                       1
# screen_size                                        1.4
# memory_size                                     0.0032
# battery_size                                     460.0
# release_date                                01-01-2013
# ...

# %% [markdown]
# Find the brand name and model name of the product having best_price

# %%
data[data['highest_price']==69999.0][['brand_name','model_name']]
# Out:
#     brand_name                                    model_name
# 298     HUAWEI  Mate Xs 8/512GB Interstellar blue (51095CSQ)

# %%
data[data['best_price']==56082.0][['brand_name','model_name']]
# Out:
#     brand_name                                    model_name
# 298     HUAWEI  Mate Xs 8/512GB Interstellar blue (51095CSQ)

# %% [markdown]
# Best Price

# %%
data.best_price.max()
# Out:
# 56082

# %% [markdown]
# Lowest price of phone value

# %%
data['lowest_price'].min()
# Out:
# 198.0

# %% [markdown]
# Model name and brand name of lowest value

# %%
data[data['lowest_price']==198.0][['brand_name','model_name']]
# Out:
#     brand_name  model_name
# 534       Nomi  i144m Blue

# %% [markdown]
# Total Counts of Nokia Phones

# %%
data[data['brand_name']=='Nokia'].count()
# Out:
# Unnamed: 0        48
# brand_name        48
# model_name        48
# os                48
# popularity        48
# best_price        48
# lowest_price      48
# highest_price     48
# sellers_amount    48
# screen_size       48
# memory_size       48
# battery_size      48
# release_date      48
# dtype: int64

# %% [markdown]
# Mean value of the best price

# %%
data['highest_price'].mean()
# Out:
# 9259.614379084967

# %% [markdown]
# Mean Value of the Lowest Price

# %%
data['lowest_price'].mean()
# Out:
# 7716.01867219917

# %% [markdown]
# Which is the latest released phone

# %%
data['release_date'].max()
# Out:
# '01-12-2020'

# %%
data[['release_date']].max()
# Out:
# release_date    01-12-2020
# dtype: object

# %%
data.head(2)
# Out:
#    Unnamed: 0 brand_name                                    model_name  \
# 0           0    ALCATEL          1 1/8GB Bluish Black (5033D-2JALUAA)
# 1           1    ALCATEL  1 5033D 1/16GB Volcano Black (5033D-2LALUAF)
#
#         os  popularity  best_price  lowest_price  highest_price  \
# 0  Android         422      1690.0        1529.0         1819.0
# 1  Android         323      1803.0        1659.0         2489.0
#
#    sellers_amount  screen_size  memory_size  battery_size release_date
# 0              36          5.0          8.0        2000.0      10-2020
# 1              36          5.0         16.0        2000.0       9-2020

# %%
#value counts of mobile phones
sns.countplot(x=data['brand_name'],order = data['brand_name'].value_counts().head().index)

# %%
data['os'].value_counts().to_list()
# Out:
# [915, 197, 103, 3, 3, 2, 1]

# %%
#countplot of operating system
sns.countplot(x=data['os'],order = data['os'].value_counts().head().index)

# %%
data['battery_size'].hist()

# %%
#Details of product having high popularity
data[data['popularity']==data['popularity'].max()][['brand_name','highest_price']]
# Out:
#     brand_name  highest_price
# 173      Apple        42999.0

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(), annot=True)

# %%
sns.relplot(x=data['highest_price'],y=data['screen_size'])
